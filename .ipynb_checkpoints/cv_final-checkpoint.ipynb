# %%
import json
import os
import sys
import pandas as pd
import numpy as np

# %% [markdown]
# # Process the train set

# %%
train_content = open('fgvc4_iMat.train.data.json','rb')
train_content = json.load(train_content)
train_anno = pd.DataFrame(train_content.get('annotations'))
train_anno
# Out:
#       labelId imageId taskId
# 0           6       1      5
# 1           7       2      6
# 2           8       3      7
# 3          10       4      9
# 4          14       5     12
# ...       ...     ...    ...
# 62083     352   42027     21
# 62084     297   42028     11
# 62085     339   42029     14
# 62086     380   42029      5
# 62087      74   42029     14
#
# [62088 rows x 3 columns]

# %%
label = json.load(open('fgvc4_iMat.filter.label_map','rb'))
label = pd.DataFrame(label.get('labelInfo'))
label
# Out:
#         labelName labelId
# 0             men       1
# 1           adult       2
# 2           black       3
# 3           women       4
# 4            flat       5
# ..            ...     ...
# 376          hole     377
# 377  chunky heels     378
# 378  ankle length     379
# 379    hollow out     380
# 380    rhinestone     381
#
# [381 rows x 2 columns]

# %%
task = json.load(open('fgvc4_iMat.filter.task_map','rb'))
task = pd.DataFrame(task.get('taskInfo'))
task
# Out:
#                    taskName taskId
# 0               shoe:gender      1
# 1                  shoe:age      2
# 2                shoe:color      3
# 3            shoe:up height      4
# 4          dress:decoration      5
# 5               dress:color      6
# 6            dress:material      7
# 7          dress:silhouette      8
# 8                 shoe:type      9
# 9         shoe:closure type     10
# 10              pants:color     11
# 11             dress:length     12
# 12           outerwear:type     13
# 13           dress:occasion     14
# 14         outerwear:gender     15
# 15           shoe:toe shape     16
# 16          outerwear:color     17
# 17           shoe:heel type     18
# 18         outerwear:collar     19
# 19            outerwear:age     20
# 20       outerwear:material     21
# 21                pants:fit     22
# 22               pants:type     23
# 23         pants:decoration     24
# 24            pants:pattern     25
# 25           pants:material     26
# 26         outerwear:length     27
# 27  outerwear:sleeve length     28
# 28                dress:age     29
# 29          shoe:decoration     30
# 30                pants:age     31
# 31             pants:gender     32
# 32        outerwear:pattern     33
# 33           shoe:flat type     34
# 34      dress:sleeve length     35
# 35            shoe:material     36
# 36            dress:pattern     37
# 37             dress:collar     38
# 38   outerwear:closure type     39
# 39             dress:gender     40
# 40   shoe:back counter type     41
# 41           shoe:pump type     42
# 42          pants:rise type     43
# 43             pants:length     44
# 44           shoe:boot type     45

# %%
train = pd.merge(train_anno,label,how='left')
train = pd.merge(train,task,how='left')
train
# Out:
#       labelId imageId taskId          labelName            taskName
# 0           6       1      5            printed    dress:decoration
# 1           7       2      6             purple         dress:color
# 2           8       3      7             velvet      dress:material
# 3          10       4      9            sneaker           shoe:type
# 4          14       5     12               midi        dress:length
# ...       ...     ...    ...                ...                 ...
# 62083     352   42027     21  synthetic leather  outerwear:material
# 62084     297   42028     11               wine         pants:color
# 62085     339   42029     14         night club      dress:occasion
# 62086     380   42029      5         hollow out    dress:decoration
# 62087      74   42029     14               club      dress:occasion
#
# [62088 rows x 5 columns]

# %%
train['tasknum'] = train['taskName'].apply(lambda x: len(x.split(':')))
train['tasknum'].describe()
# All the images have two tasks splitted by :
# Out:
# count    62088.0
# mean         2.0
# std          0.0
# min          2.0
# 25%          2.0
# 50%          2.0
# 75%          2.0
# max          2.0
# Name: tasknum, dtype: float64

# %%
train['task1'] = train['taskName'].apply(lambda x: x.split(':')[0])
train['task2'] = train['taskName'].apply(lambda x: x.split(':')[1])
train
# Out:
#       labelId imageId taskId          labelName            taskName  tasknum  \
# 0           6       1      5            printed    dress:decoration        2
# 1           7       2      6             purple         dress:color        2
# 2           8       3      7             velvet      dress:material        2
# 3          10       4      9            sneaker           shoe:type        2
# 4          14       5     12               midi        dress:length        2
# ...       ...     ...    ...                ...                 ...      ...
# 62083     352   42027     21  synthetic leather  outerwear:material        2
# 62084     297   42028     11               wine         pants:color        2
# 62085     339   42029     14         night club      dress:occasion        2
# 62086     380   42029      5         hollow out    dress:decoration        2
# 62087      74   42029     14               club      dress:occasion        2
#
#            task1       task2
# 0          dress  decoration
# 1          dress       color
# 2          dress    material
# 3           shoe        type
# 4          dress      length
# ...          ...         ...
# 62083  outerwear    material
# 62084      pants       color
# 62085      dress    occasion
# 62086      dress  decoration
# 62087      dress    occasion
#
# [62088 rows x 8 columns]

# %%
# Find the valid images
from PIL import Image
files = os.listdir('./train_images/')
valid_imageid = []
for file in files:
    try:
        fp = open('./train_images/'+file,'rb')
        Image.open(fp)
        fp.close()
        valid_imageid.append(file[:-4])
    except:
        continue
print(len(valid_imageid))
# Have 24644 valid images in total
# Out:
# 24644

# %%
# Select the information of valid images
train = train[train['imageId'].isin(set(valid_imageid))]

# %%
train
# Out:
#       labelId imageId taskId   labelName          taskName  tasknum  task1  \
# 0           6       1      5     printed  dress:decoration        2  dress
# 1           7       2      6      purple       dress:color        2  dress
# 2           8       3      7      velvet    dress:material        2  dress
# 3          10       4      9     sneaker         shoe:type        2   shoe
# 7          23       7      6         red       dress:color        2  dress
# ...       ...     ...    ...         ...               ...      ...    ...
# 62077      20   42023     11        blue       pants:color        2  pants
# 62078     289   42024     26     goretex    pants:material        2  pants
# 62085     339   42029     14  night club    dress:occasion        2  dress
# 62086     380   42029      5  hollow out  dress:decoration        2  dress
# 62087      74   42029     14        club    dress:occasion        2  dress
#
#             task2
# 0      decoration
# 1           color
# 2        material
# 3            type
# 7           color
# ...           ...
# 62077       color
# 62078    material
# 62085    occasion
# 62086  decoration
# 62087    occasion
#
# [37336 rows x 8 columns]

# %%
train4base = train[['imageId','task1']].drop_duplicates()
train4base
# This has 24557 rows > 24644 which means some of the images have more than one classes
# Out:
#       imageId      task1
# 0           1      dress
# 1           2      dress
# 2           3      dress
# 3           4       shoe
# 7           7      dress
# ...       ...        ...
# 62072   42020  outerwear
# 62073   42021  outerwear
# 62075   42023      pants
# 62078   42024      pants
# 62085   42029      dress
#
# [24667 rows x 2 columns]

# %%
classnum = train4base.groupby('imageId').count().sort_values('task1',ascending=False).reset_index().rename({'task1':'classnum'},axis=1)
train4base = pd.merge(train4base,classnum,how='left')
train4base[train4base['classnum']>=2]
# Out:
#       imageId      task1  classnum
# 175       292      dress         2
# 176       292       shoe         2
# 1166     2097  outerwear         2
# 1167     2097      pants         2
# 2267     4090  outerwear         2
# 2268     4090       shoe         2
# 2694     4884  outerwear         2
# 2695     4884      pants         2
# 3232     5822  outerwear         2
# 3233     5822      pants         2
# 3696     6631  outerwear         2
# 3697     6631       shoe         2
# 6309    11124      pants         2
# 6310    11124  outerwear         2
# 6465    11378      dress         2
# 6466    11378       shoe         2
# 7056    12443      pants         2
# 7057    12443  outerwear         2
# 7654    13466      dress         2
# 7655    13466       shoe         2
# 7662    13479  outerwear         2
# 7663    13479      pants         2
# 7681    13515  outerwear         2
# 7682    13515      pants         2
# 8901    15601      dress         2
# 8902    15601  outerwear         2
# 13076   22732  outerwear         2
# 13077   22732      pants         2
# 14288   24854      pants         2
# 14289   24854  outerwear         2
# 15441   26795  outerwear         2
# 15442   26795      pants         2
# 15631   27113  outerwear         2
# 15632   27113      pants         2
# 16189   28016  outerwear         2
# 16190   28016      pants         2
# 16346   28282  outerwear         2
# 16347   28282      pants         2
# 18516   31917  outerwear         2
# 18517   31917      pants         2
# 19154   32978       shoe         2
# 19155   32978  outerwear         2
# 21983   37654       shoe         2
# 21984   37654      pants         2
# 23068   39406  outerwear         2
# 23069   39406      pants         2

# %%
import matplotlib.pyplot as plt
i292 = open('./train_images/292.jpg','rb')
i292 = Image.open(i292)
fig = plt.figure()
plt.imshow(i292)
# In image 292, there are indeed both dress and shoes

# %%
train4base.groupby('task1').count() 
# Dress and outerwear are more than pants and shoe but the discrepancy is acceptable
# Out:
#            imageId  classnum
# task1
# dress         7555      7555
# outerwear     7348      7348
# pants         5393      5393
# shoe          4371      4371

# %%
train4base.to_csv('train4base.csv')
train.to_csv('train.csv')

# %% [markdown]
# # Process the validation set

# %%
validation_content = open('fgvc4_iMat.validation.data','rb')
validation_content = json.load(validation_content)
validation_anno = pd.DataFrame(validation_content.get('annotations'))
validation_anno
# Out:
#       taskId imageId labelId
# 0          1       1       1
# 1          2       1       2
# 2          3       1       3
# 3         10       2      11
# 4          4       3      18
# ...      ...     ...     ...
# 12401      1    8429       1
# 12402     26    8430     289
# 12403      2    8431       2
# 12404      1    8431       4
# 12405     19    8432     372
#
# [12406 rows x 3 columns]

# %%
label = json.load(open('fgvc4_iMat.filter.label_map','rb'))
label = pd.DataFrame(label.get('labelInfo'))
task = json.load(open('fgvc4_iMat.filter.task_map','rb'))
task = pd.DataFrame(task.get('taskInfo'))

# %%
validation = pd.merge(validation_anno,label,how='left')
validation = pd.merge(validation,task,how='left')
validation['task1'] = validation['taskName'].apply(lambda x: x.split(':')[0])
validation['task2'] = validation['taskName'].apply(lambda x: x.split(':')[1])
validation
# Out:
#       taskId imageId labelId labelName           taskName      task1  \
# 0          1       1       1       men        shoe:gender       shoe
# 1          2       1       2     adult           shoe:age       shoe
# 2          3       1       3     black         shoe:color       shoe
# 3         10       2      11    slipon  shoe:closure type       shoe
# 4          4       3      18       low     shoe:up height       shoe
# ...      ...     ...     ...       ...                ...        ...
# 12401      1    8429       1       men        shoe:gender       shoe
# 12402     26    8430     289   goretex     pants:material      pants
# 12403      2    8431       2     adult           shoe:age       shoe
# 12404      1    8431       4     women        shoe:gender       shoe
# 12405     19    8432     372    double   outerwear:collar  outerwear
#
#               task2
# 0            gender
# 1               age
# 2             color
# 3      closure type
# 4         up height
# ...             ...
# 12401        gender
# 12402      material
# 12403           age
# 12404        gender
# 12405        collar
#
# [12406 rows x 7 columns]

# %%
# Find the valid images
from PIL import Image
files = os.listdir('/Users/ethancolt/Desktop/Deep Learning for Computer Vision/Final/validation_images/')
valid_imageid = []
for file in files:
    try:
        fp = open('/Users/ethancolt/Desktop/Deep Learning for Computer Vision/Final/validation_images/'+file,'rb')
        Image.open(fp)
        fp.close()
        valid_imageid.append(file[:-4])
    except:
        continue
print(len(valid_imageid))
# Have 4951 valid images in total
# Out:
# 4951

# %%
validation = validation[validation['imageId'].isin(set(valid_imageid))]
validation
# Out:
#       taskId imageId labelId labelName            taskName      task1  \
# 0          1       1       1       men         shoe:gender       shoe
# 1          2       1       2     adult            shoe:age       shoe
# 2          3       1       3     black          shoe:color       shoe
# 3         10       2      11    slipon   shoe:closure type       shoe
# 5         14       4      26   wedding      dress:occasion      dress
# ...      ...     ...     ...       ...                 ...        ...
# 12399     21    8427      64     satin  outerwear:material  outerwear
# 12400     14    8428      26   wedding      dress:occasion      dress
# 12401      1    8429       1       men         shoe:gender       shoe
# 12402     26    8430     289   goretex      pants:material      pants
# 12405     19    8432     372    double    outerwear:collar  outerwear
#
#               task2
# 0            gender
# 1               age
# 2             color
# 3      closure type
# 5          occasion
# ...             ...
# 12399      material
# 12400      occasion
# 12401        gender
# 12402      material
# 12405        collar
#
# [7387 rows x 7 columns]

# %%
validation4base = validation[['imageId','task1']].drop_duplicates()
validation4base
# Still, the validation set has some images with multiple classes
# Out:
#       imageId      task1
# 0           1       shoe
# 3           2       shoe
# 5           4      dress
# 6           5      dress
# 8           7       shoe
# ...       ...        ...
# 12398    8427  outerwear
# 12400    8428      dress
# 12401    8429       shoe
# 12402    8430      pants
# 12405    8432  outerwear
#
# [4960 rows x 2 columns]

# %%
classnum = validation4base.groupby('imageId').count().sort_values('task1',ascending=False).reset_index().rename({'task1':'classnum'},axis=1)
validation4base = pd.merge(validation4base,classnum,how='left')
validation4base[validation4base['classnum']>=2]
# Out:
#      imageId      task1  classnum
# 61       133  outerwear         2
# 62       133      pants         2
# 202      367  outerwear         2
# 203      367      pants         2
# 465      825  outerwear         2
# 466      825       shoe         2
# 1007    1743      pants         2
# 1008    1743      dress         2
# 1524    2653      dress         2
# 1525    2653  outerwear         2
# 1694    2929  outerwear         2
# 1695    2929      pants         2
# 2275    3915       shoe         2
# 2276    3915      pants         2
# 2822    4821       shoe         2
# 2823    4821      dress         2
# 4256    7238  outerwear         2
# 4257    7238      pants         2

# %%
validation4base.to_csv('validation4base.csv')
validation.to_csv('validation.csv')

# %% [markdown]
# **下面是垃圾**

# %%
content = open('val2017.json','rb')
content = json.load(content)
pd.DataFrame(content.get('annotations'))
# Out:
#        image_id  category_id      id
# 0             0            0       0
# 1            11            0      11
# 2            18            0      18
# 3            21            0      21
# 4            37            0      37
# ...         ...          ...     ...
# 95981    675063         5086  675063
# 95982    675110         5086  675110
# 95983    675152         5087  675152
# 95984    675153         5087  675153
# 95985    675162         5088  675162
#
# [95986 rows x 3 columns]

# %%
pd.DataFrame(content.get('images'))
# Out:
#        license                                          file_name  \
# 0            3  train_val_images/Mammalia/Marmota flaviventris...
# 1            3  train_val_images/Mammalia/Marmota flaviventris...
# 2            3  train_val_images/Mammalia/Marmota flaviventris...
# 3            3  train_val_images/Mammalia/Marmota flaviventris...
# 4            3  train_val_images/Mammalia/Marmota flaviventris...
# ...        ...                                                ...
# 95981        3  train_val_images/Aves/Columba livia/78a62bdb5a...
# 95982        3  train_val_images/Aves/Columba livia/e37f20f553...
# 95983        3  train_val_images/Insecta/Notarctia proxima/8ea...
# 95984        3  train_val_images/Insecta/Notarctia proxima/add...
# 95985        3  train_val_images/Aves/Piranga bidentata/181405...
#
#              rights_holder  height  width      id
# 0                   zhil67     533    800       0
# 1               Joe Miller     800    800      11
# 2            salmonskyview     600    800      18
# 3                   psweet     800    735      21
# 4            mikewitkowski     800    600      37
# ...                    ...     ...    ...     ...
# 95981             diegou10     800    600  675063
# 95982            rosemarie     800    600  675110
# 95983  Juan Cruzado Cortés     474    800  675152
# 95984         Liam O'Brien     694    800  675153
# 95985        Kenneth Bader     600    800  675162
#
# [95986 rows x 6 columns]

# %%
pd.DataFrame(content.get('categories'))
# Out:
#      supercategory    id                    name
# 0          Insecta  1916  Nicrophorus tomentosus
# 1          Insecta  3808       Halyomorpha halys
# 2          Plantae  3516            Betula lenta
# 3            Fungi  2533      Hericium erinaceus
# 4         Animalia  4854     Harpaphe haydeniana
# ...            ...   ...                     ...
# 5084       Plantae  3297      Cynoglossum grande
# 5085       Plantae   798          Malva moschata
# 5086       Insecta  4643         Phanaeus vindex
# 5087       Insecta  2901       Agraulis vanillae
# 5088         Fungi  4616        Letharia vulpina
#
# [5089 rows x 3 columns]

# %%
import json
import pandas as pd

# %%
content = open('fgvc4_iMat.train.data.json','rb')
content = json.load(content)
pd.DataFrame(content.get('annotations'))
# Out:
#       labelId imageId taskId
# 0           6       1      5
# 1           7       2      6
# 2           8       3      7
# 3          10       4      9
# 4          14       5     12
# ...       ...     ...    ...
# 62083     352   42027     21
# 62084     297   42028     11
# 62085     339   42029     14
# 62086     380   42029      5
# 62087      74   42029     14
#
# [62088 rows x 3 columns]

# %%
pd.DataFrame(content.get('images'))
# Out:
#                                                      url imageId
# 0      [http://im28.gulfup.com/2012-04-14/13344248029...       1
# 1      [http://dtpmhvbsmffsz.cloudfront.net/posts/201...       2
# 2      [http://ep.yimg.com/ay/yhst-2003691491864/new-...       3
# 3      [http://sneakerlover.de/wp-content/uploads/201...       4
# 4      [http://allplussizedresses.com/wp-content/uplo...       5
# ...                                                  ...     ...
# 42024  [http://i01.i.aliimg.com/wsphoto/v0/556409753/...   42025
# 42025  [http://img.alibaba.com/wsphoto/v0/514341333/H...   42026
# 42026  [http://bingua.com/images/cotizacion_images/20...   42027
# 42027  [http://nattstadcdn.com/6/1000000/970000/96149...   42028
# 42028  [http://www.dhresource.com/0x0s/f2-albu-g3-M01...   42029
#
# [42029 rows x 2 columns]

# %%
import sys
import requests
data = pd.DataFrame(content.get('images')).iloc[40000:,:]
def download_image(urls,imageid):
    while len(urls)>0:
        try:
            with open('./train/'+imageid+'.jpg','wb') as f:
                img = requests.get(urls[0],timeout=1).content
                f.write(img)
                f.close
            urls = []
        except:
            urls = urls[1:]           
    return
error = []
for imageid,url in zip(data['imageId'],data['url']):
    try:
        download_image(url,imageid)
    except:
        error.append(imageid)
    sys.stdout.write('\rn°: {}'.format(imageid))
# Out:
# n°: 42029

# %%
content = open('fgvc4_iMat.validation.data','rb')
content = json.load(content)
pd.DataFrame(content.get('images'))
# Out:
#                                                     url imageId
# 0     [https://s-media-cache-ak0.pinimg.com/original...       1
# 1     [https://s-media-cache-ak0.pinimg.com/736x/bd/...       2
# 2     [http://cdn.iofferphoto.com/img3/item/612/976/...       3
# 3     [http://static.wixstatic.com/media/435eb4_c5a9...       4
# 4     [http://couturedressesuk.com/image/cache/data/...       5
# ...                                                 ...     ...
# 8427  [http://picvpic.com/fashion101/wp-content/uplo...    8428
# 8428  [http://163.musicway.cn/order/itingsid-null/sd...    8429
# 8429  [http://i.stpost.com/product~p~152JM_01~1500.1...    8430
# 8430  [http://www.atopshoe.com/wp-content/uploads/20...    8431
# 8431  [http://ecx.images-amazon.com/images/I/51iArGS...    8432
#
# [8432 rows x 2 columns]

# %%
import sys
import requests
data = pd.DataFrame(content.get('images')).iloc[2000:,:]
def download_image(urls,imageid):
    while len(urls)>0:
        try:
            with open('./validation/'+imageid+'.jpg','wb') as f:
                img = requests.get(urls[0],timeout=1).content
                f.write(img)
                f.close
            urls = []
        except:
            urls = urls[1:]           
    return
error = []
for imageid,url in zip(data['imageId'],data['url']):
    try:
        download_image(url,imageid)
    except:
        error.append(imageid)
    sys.stdout.write('\rn°: {}'.format(imageid))
# Out:
# n°: 2000

# %%
f = open('./train/40.jpg','rb')
print(f)
# Out:
# <_io.BufferedReader name='./train/40.jpg'>

# %%
from PIL import Image
import os
files = os.listdir('./train/')
error = []
for file in files:
    try:
        fp = open('./train/'+file,'rb')
        Image.open(fp)
        fp.close()
    except:
        error.append(file)
print(error)
# Out:
# ['40270.jpg', '12250.jpg', '6372.jpg', '18741.jpg', '26877.jpg', '13614.jpg', '24906.jpg', '8377.jpg', '15271.jpg', '26888.jpg', '30754.jpg', '24735.jpg', '27200.jpg', '88.jpg', '23700.jpg', '10123.jpg', '4015.jpg', '26485.jpg', '30581.jpg', '5479.jpg', '13358.jpg', '4997.jpg', '8607.jpg', '8161.jpg', '30556.jpg', '17857.jpg', '30230.jpg', '27980.jpg', '23270.jpg', '10862.jpg', '29985.jpg', '412.jpg', '374.jpg', '40660.jpg', '11349.jpg', '16354.jpg', '18351.jpg', '10719.jpg', '11407.jpg', '20143.jpg', '9492.jpg', '3829.jpg', '25013.jp
jpg', '18757.jpg', '41144.jpg', '12252.jpg', '18019.jpg', '835.jpg', '21854.jpg', '20592.jpg', '14637.jpg', '4239.jpg', '4563.jpg', '7095.jpg', '28653.jpg', '30034.jpg', '7903.jpg', '7254.jpg', '11575.jpg', '3026.jpg', '13410.jpg', '40706.jpg', '40060.jpg', '6176.jpg', '19667.jpg', '22829.jpg', '372.jpg', '10864.jpg', '19840.jpg', '20031.jpg', '3973.jpg', '25149.jpg', '29820.jpg', '17716.jpg', '10079.jpg', '6758.jpg', '17064.jpg', '13202.jpg', '6994.jpg', '11373.jpg', '40882.jpg', '41544.jpg', '10723.jpg', '25954.jpg', '1779.jpg', '16346.jpg', '16420.jpg', '560.jpg', '28525.jpg', '41593.jpg', '40699.jpg', '6957.jpg', '574.jpg', '12861.jpg', '25997.jpg', '.DS_Store', '13766.jpg', '28096.jpg', '24684.jpg', '11159.jpg', '9899.jpg', '40302.jpg', '14753.jpg', '28041.jpg', '21703.jpg', '5090.jpg', '762.jpg', '20409.jpg', '29405.jpg', '30154.jpg', '29411.jpg', '16187.jpg', '13940.jpg', '26723.jpg', '16186.jpg', '8589.jpg', '24120.jpg', '22579.jpg', '21702.jpg', '30169.jpg', '41009.jpg', '14020.jpg', '6567.jpg', '944.jpg ...

# %%
len(error)
# Out:
# 1998

# %%
error = error+os.listdir('./fail_train/')
error
# Out:
# ['40270.jpg',
#  '12250.jpg',
#  '6372.jpg',
#  '18741.jpg',
#  '26877.jpg',
#  '13614.jpg',
#  '24906.jpg',
#  '8377.jpg',
#  '15271.jpg',
#  '26888.jpg',
#  '30754.jpg',
#  '24735.jpg',
#  '27200.jpg',
#  '88.jpg',
#  '23700.jpg',
#  '10123.jpg',
#  '4015.jpg',
#  '26485.jpg',
#  '30581.jpg',
#  '5479.jpg',
#  '13358.jpg',
#  '4997.jpg',
#  '8607.jpg',
#  '8161.jpg',
#  '30556.jpg',
#  '17857.jpg',
#  '30230.jpg',
#  '27980.jpg',
#  '23270.jpg',
#  '10862.jpg',
#  '29985.jpg',
#  '412.jpg',
#  '374.jpg',
#  '40660.jpg',
#  '11349.jpg',
#  '16354.jpg',
#  '18351.jpg',
#  '10719.jpg',
#  '11407.jpg',
#  '20143.jpg',
#  '9492.jpg',
#  '3829.jpg',
#  '25013.jpg',
#  '28523.jpg',
#  '9647.jpg',
#  '9121.jpg',
#  '40310.jpg',
#  '13990.jpg',
#  '5733.jpg',
#  '8571.jpg',
#  '18812.jpg',
#  '11188.jpg',
#  '9848.jpg',
#  '28735.jpg',
#  '25577.jpg',
#  '24669.jpg',
#  '764.jpg',
#  '28720.jpg',
#  '4389.jpg',
#  '21062.jpg',
#  '20368.jpg',
#  '21076.jpg',
#  '13952.jpg',
#  '24654.jpg',
#  '1232.jpg',
#  '28091.jpg',
#  '14740.jpg',
#  '956.jpg',
#  '21937.jpg',
#  '4835.jpg',
#  '2288.jpg',
#  '3828.jpg',
#  '12696.jpg',
#  '10081.jpg',
#  '4809.jpg',
#  '26241.jpg',
#  '10095.jpg',
#  '20747.jpg',
#  '8822.jpg',
#  '26444.jpg',
#  '41352.jpg',
#  '8605.jpg',
#  '23299.jpg',
#  '26487.jpg',
#  '10135.jpg',
#  '18958.jpg',
#  '22408.jpg',
#  '1386.jpg',
#  '25373.jpg',
#  '5876.jpg',
#  '20223.jpg',
#  '27558.jpg',
#  '30024.jpg',
#  '18025.jpg',
#  '24904.jpg',
#  '3546.jpg',
#  '18757.jpg',
#  '41144.jpg',
#  '12252.jpg',
#  '18019.jpg',
#  '835.jpg',
#  '21854.jpg',
#  '20592.jpg',
#  '14637.jpg',
#  '4239.jpg',
#  '4563.jpg',
#  '7095.jpg',
#  '28653.jpg',
#  '30034.jpg',
#  '7903.jpg',
#  '7254.jpg',
#  '11575.jpg',
#  '3026.jpg',
#  '13410.jpg',
#  '40706.jpg',
#  '40060.jpg',
#  '6176.jpg',
#  '19667.jpg',
#  '22829.jpg',
#  '372.jpg',
#  '10864.jpg',
#  '19840.jpg',
#  '20031.jpg',
#  '3973.jpg',
#  '25149.jpg',
#  '29820.jpg',
#  '17716.jpg',
#  '10079.jpg',
#  '6758.jpg',
#  '17064.jpg',
#  '13202.jpg',
#  '6994.jpg',
#  '11373.jpg',
#  '40882.jpg',
#  '41544.jpg',
#  '10723.jpg',
#  '25954.jpg',
#  '1779.jpg',
#  '16346.jpg',
#  '16420.jpg',
#  '560.jpg',
#  '28525.jpg',
#  '41593.jpg',
#  '40699.jpg',
#  '6957.jpg',
#  '574.jpg',
#  '12861.jpg',
#  '25997.jpg',
#  '.DS_Store',
#  '13766.jpg',
#  '28096.jpg',
#  '24684.jpg',
#  '11159.jpg',
#  '9899.jpg',
#  '40302.jpg',
#  '14753.jpg',
#  '28041.jpg',
#  '21703.jpg',
#  '5090.jpg',
#  '762.jpg',
#  '20409.jpg',
#  '29405.jpg',
#  '30154.jpg',
#  '29411.jpg',
#  '16187.jpg',
#  '13940.jpg',
#  '26723.jpg',
#  '16186.jpg',
#  '8589.jpg',
#  '24120.jpg',
#  '22579.jpg',
#  '21702.jpg',
#  '30169.jpg',
#  '41009.jpg',
#  '14020.jpg',
#  '6567.jpg',
#  '944.jpg',
#  '40471.jpg',
#  '2701.jpg',
#  '29389.jpg',
#  '3351.jpg',
#  '11164.jpg',
#  '10093.jpg',
#  '24336.jpg',
#  '12690.jpg',
#  '27165.jpg',
#  '1787.jpg',
#  '6942.jpg',
#  '24478.jpg',
#  '4833.jpg',
#  '16421.jpg',
#  '12653.jpg',
#  '14222.jpg',
#  '9456.jpg',
#  '15882.jpg',
#  '25941.jpg',
#  '40115.jpg',
#  '16353.jpg',
#  '8006.jpg',
#  '5522.jpg',
#  '41223.jpg',
#  '6981.jpg',
#  '3621.jpg',
#  '4628.jpg',
#  '17071.jpg',
#  '1988.jpg',
#  '15921.jpg',
#  '3966.jpg',
#  '40908.jpg',
#  '26441.jpg',
#  '9287.jpg',
#  '10865.jpg',
#  '18587.jpg',
#  '21306.jpg',
#  '373.jpg',
#  '25612.jpg',
#  '4774.jpg',
#  '1456.jpg',
#  '41657.jpg',
#  '3533.jpg',
#  '15212.jpg',
#  '7755.jpg',
#  '24971.jpg',
#  '23993.jpg',
#  '21148.jpg',
#  '11935.jpg',
#  '18939.jpg',
#  '23763.jpg',
#  '115.jpg',
#  '1481.jpg',
#  '41469.jpg',
#  '3719.jpg',
#  '4076.jpg',
#  '14454.jpg',
#  '6113.jpg',
#  '12025.jpg',
#  '19170.jpg',
#  '20097.jpg',
#  '8880.jpg',
#  '8116.jpg',
#  '4738.jpg',
#  '25886.jpg',
#  '16280.jpg',
#  '24554.jpg',
#  '8843.jpg',
#  '40788.jpg',
#  '28420.jpg',
#  '19825.jpg',
#  '23561.jpg',
#  '6067.jpg',
#  '16337.jpg',
#  '11316.jpg',
#  '3889.jpg',
#  '7437.jpg',
#  '17001.jpg',
#  '41253.jpg',
#  '22723.jpg',
#  '14291.jpg',
#  '26223.jpg',
#  '21558.jpg',
#  '10785.jpg',
#  '20120.jpg',
#  '3862.jpg',
#  '1085.jpg',
#  '19951.jpg',
#  '30469.jpg',
#  '4857.jpg',
#  '6503.jpg',
#  '6265.jpg',
#  '3335.jpg',
#  '15372.jpg',
#  '1244.jpg',
#  '17571.jpg',
#  '5988.jpg',
#  '24636.jpg',
#  '7812.jpg',
#  '21028.jpg',
#  '29460.jpg',
#  '16690.jpg',
#  '41086.jpg',
#  '3490.jpg',
#  '707.jpg',
#  '28742.jpg',
#  '5793.jpg',
#  '7184.jpg',
#  '23170.jpg',
#  '4498.jpg',
#  '27302.jpg',
#  '30118.jpg',
#  '14086.jpg',
#  '41911.jpg',
#  '29461.jpg',
#  '10592.jpg',
#  '40428.jpg',
#  '11101.jpg',
#  '24804.jpg',
#  '24810.jpg',
#  '3334.jpg',
#  '11115.jpg',
#  '909.jpg',
#  '26949.jpg',
#  '14045.jpg',
#  '40372.jpg',
#  '19207.jpg',
#  '19213.jpg',
#  '28227.jpg',
#  '5590.jpg',
#  '21203.jpg',
#  '20121.jpg',
#  '538.jpg',
#  '9382.jpg',
#  '17772.jpg',
#  '13514.jpg',
#  '15171.jpg',
#  '13500.jpg',
#  '19777.jpg',
#  '24390.jpg',
#  '40164.jpg',
#  '4922.jpg',
#  '15978.jpg',
#  '28347.jpg',
#  '11288.jpg',
#  '12781.jpg',
#  '12795.jpg',
#  '25887.jpg',
#  '7230.jpg',
#  '1133.jpg',
#  '20928.jpg',
#  '16242.jpg',
#  '14455.jpg',
#  '6674.jpg',
#  '8659.jpg',
#  '40776.jpg',
#  '12756.jpg',
#  '9235.jpg',
#  '11539.jpg',
#  '5180.jpg',
#  '28637.jpg',
#  '13879.jpg',
#  '23004.jpg',
#  '5194.jpg',
#  '16915.jpg',
#  '26626.jpg',
#  '24025.jpg',
#  '19429.jpg',
#  '41124.jpg',
#  '16068.jpg',
#  '17376.jpg',
#  '15207.jpg',
#  '12568.jpg',
#  '7998.jpg',
#  '14657.jpg',
#  '13138.jpg',
#  '16040.jpg',
#  '10431.jpg',
#  '16730.jpg',
#  '30091.jpg',
#  '8926.jpg',
#  '8932.jpg',
#  '17951.jpg',
#  '1241.jpg',
#  '13706.jpg',
#  '41726.jpg',
#  '3456.jpg',
#  '41040.jpg',
#  '8265.jpg',
#  '13074.jpg',
#  '23821.jpg',
#  '16124.jpg',
#  '4463.jpg',
#  '2760.jpg',
#  '18690.jpg',
#  '41097.jpg',
#  '23612.jpg',
#  '21005.jpg',
#  '9184.jpg',
#  '24627.jpg',
#  '27448.jpg',
#  '29302.jpg',
#  '25538.jpg',
#  '4489.jpg',
#  '1297.jpg',
#  '5783.jpg',
#  '28961.jpg',
#  '924.jpg',
#  '24197.jpg',
#  '14054.jpg',
#  '26780.jpg',
#  '19570.jpg',
#  '6275.jpg',
#  '1254.jpg',
#  '11110.jpg',
#  '8264.jpg',
#  '3331.jpg',
#  '40808.jpg',
#  '9393.jpg',
#  '27139.jpg',
#  '12182.jpg',
#  '12814.jpg',
#  '23377.jpg',
#  '5581.jpg',
#  '1081.jpg',
#  '22096.jpg',
#  '25935.jpg',
#  '12141.jpg',
#  '13539.jpg',
#  '13277.jpg',
#  '8072.jpg',
#  '17011.jpg',
#  '3133.jpg',
#  '41243.jpg',
#  '18450.jpg',
#  '17763.jpg',
#  '11312.jpg',
#  '10193.jpg',
#  '9581.jpg',
#  '15955.jpg',
#  '30525.jpg',
#  '10187.jpg',
#  '23565.jpg',
#  '12960.jpg',
#  '40798.jpg',
#  '18281.jpg',
#  '11528.jpg',
#  '16253.jpg',
#  '30294.jpg',
#  '29935.jpg',
#  '15772.jpg',
#  '26145.jpg',
#  '14849.jpg',
#  '16938.jpg',
#  '21158.jpg',
#  '7962.jpg',
#  '24008.jpg',
#  '2826.jpg',
#  '41848.jpg',
#  '30069.jpg',
#  '3286.jpg',
#  '14652.jpg',
#  '26186.jpg',
#  '16045.jpg',
#  ...]

# %%
len(error)
# Out:
# 14793

# %%
fp = open('train_failist.txt','w')
for e in error:
    fp.write(e+'\n')
fp.close
# Out:
# <function TextIOWrapper.close()>

# %%
fp = open('train_failist1.txt')
a = [f[:-1] for f in fp.readlines()]
a
# Out:
# ['34297.jpg',
#  '35189.jpg',
#  '36480.jpg',
#  '35837.jpg',
#  '34283.jpg',
#  '38491.jpg',
#  '32802.jpg',
#  '30967.jpg',
#  '30032.jpg',
#  '36443.jpg',
#  '39770.jpg',
#  '32625.jpg',
#  '34254.jpg',
#  '38308.jpg',
#  '30754.jpg',
#  '30998.jpg',
#  '34526.jpg',
#  '34240.jpg',
#  '37749.jpg',
#  '39764.jpg',
#  '31338.jpg',
#  '32619.jpg',
#  '33507.jpg',
#  '39994.jpg',
#  '31310.jpg',
#  '37007.jpg',
#  '33261.jpg',
#  '33275.jpg',
#  '35604.jpg',
#  '38320.jpg',
#  '37013.jpg',
#  '39980.jpg',
#  '37775.jpg',
#  '35162.jpg',
#  '36682.jpg',
#  '33922.jpg',
#  '33936.jpg',
#  '38863.jpg',
#  '30581.jpg',
#  '31847.jpg',
#  '34917.jpg',
#  '38693.jpg',
#  '38687.jpg',
#  '38914.jpg',
#  '30390.jpg',
#  '34684.jpg',
#  '31924.jpg',
#  '34874.jpg',
#  '38096.jpg',
#  '38928.jpg',
#  '36911.jpg',
#  '32222.jpg',
#  '38069.jpg',
#  '30435.jpg',
#  '39411.jpg',
#  '33882.jpg',
#  '34135.jpg',
#  '32550.jpg',
#  '39405.jpg',
#  '30421.jpg',
#  '34647.jpg',
#  '38055.jpg',
#  '33100.jpg',
#  '34109.jpg',
#  '33666.jpg',
#  '31071.jpg',
#  '31065.jpg',
#  '37372.jpg',
#  '32785.jpg',
#  '36285.jpg',
#  '36291.jpg',
#  '32949.jpg',
#  '37831.jpg',
#  '32961.jpg',
#  '39834.jpg',
#  '38294.jpg',
#  '35968.jpg',
#  '38280.jpg',
#  '39820.jpg',
#  '34337.jpg',
#  '36520.jpg',
#  '30637.jpg',
#  '37158.jpg',
#  '39175.jpg',
#  '32020.jpg',
#  '34451.jpg',
#  '35997.jpg',
#  '32034.jpg',
#  '35983.jpg',
#  '36534.jpg',
#  '38519.jpg',
#  '32752.jpg',
#  '37602.jpg',
#  '38531.jpg',
#  '35015.jpg',
#  '35773.jpg',
#  '33302.jpg',
#  '38257.jpg',
#  '39149.jpg',
#  '35767.jpg',
#  '31267.jpg',
#  '37616.jpg',
#  '38525.jpg',
#  '30179.jpg',
#  '34478.jpg',
#  '31500.jpg',
#  '38524.jpg',
#  '37617.jpg',
#  '36509.jpg',
#  '35000.jpg',
#  '33465.jpg',
#  '39148.jpg',
#  '35772.jpg',
#  '36253.jpg',
#  '39160.jpg',
#  '30622.jpg',
#  '35982.jpg',
#  '34444.jpg',
#  '32753.jpg',
#  '34322.jpg',
#  '30144.jpg',
#  '36521.jpg',
#  '32747.jpg',
#  '32021.jpg',
#  '39174.jpg',
#  '30805.jpg',
#  '32974.jpg',
#  '30811.jpg',
#  '35799.jpg',
#  '36290.jpg',
#  '30839.jpg',
#  '32948.jpg',
#  '32784.jpg',
#  '37824.jpg',
#  '30193.jpg',
#  '39809.jpg',
#  '37415.jpg',
#  '38040.jpg',
#  '35570.jpg',
#  '36079.jpg',
#  '31716.jpg',
#  '38732.jpg',
#  '33667.jpg',
#  '35216.jpg',
#  '39404.jpg',
#  '37429.jpg',
#  '30346.jpg',
#  '33897.jpg',
#  '35558.jpg',
#  '34646.jpg',
#  '38068.jpg',
#  '34652.jpg',
#  '39410.jpg',
#  '36723.jpg',
#  '30352.jpg',
#  '33868.jpg',
#  '31919.jpg',
#  '34875.jpg',
#  '33854.jpg',
#  '32592.jpg',
#  '30385.jpg',
#  '34685.jpg',
#  '36086.jpg',
#  '31931.jpg',
#  '36938.jpg',
#  '37561.jpg',
#  '31110.jpg',
#  '31676.jpg',
#  '38134.jpg',
#  '30568.jpg',
#  '33061.jpg',
#  '35410.jpg',
#  '35404.jpg',
#  '31662.jpg',
#  '37213.jpg',
#  '37575.jpg',
#  '38646.jpg',
#  '39558.jpg',
#  '33713.jpg',
#  '30232.jpg',
#  '36643.jpg',
#  '39216.jpg',
#  '38108.jpg',
#  '39202.jpg',
#  '33049.jpg',
#  '34726.jpg',
#  '32431.jpg',
#  '34040.jpg',
#  '37549.jpg',
#  '39564.jpg',
#  '36657.jpg',
#  '31138.jpg',
#  '38849.jpg',
#  '38691.jpg',
#  '34915.jpg',
#  '34901.jpg',
#  '36870.jpg',
#  '35389.jpg',
#  '33920.jpg',
#  '36680.jpg',
#  '31851.jpg',
#  '32380.jpg',
#  '32394.jpg',
#  '36694.jpg',
#  '33934.jpg',
#  '38450.jpg',
#  '31306.jpg',
#  '36469.jpg',
#  '39982.jpg',
#  '31460.jpg',
#  '35606.jpg',
#  '39014.jpg',
#  '32141.jpg',
#  '34530.jpg',
#  '36441.jpg',
#  '39772.jpg',
#  '30030.jpg',
#  '39766.jpg',
#  '30024.jpg',
#  '32633.jpg',
#  '34524.jpg',
#  '36333.jpg',
#  '39955.jpg',
#  '39799.jpg',
#  '32814.jpg',
#  '30965.jpg',
#  '32182.jpg',
#  '39969.jpg',
#  '37944.jpg',
#  '34295.jpg',
#  '34281.jpg',
#  '37950.jpg',
#  '30959.jpg',
#  '32196.jpg',
#  '32810.jpg',
#  '37968.jpg',
#  '39789.jpg',
#  '32804.jpg',
#  '32192.jpg',
#  '36492.jpg',
#  '39979.jpg',
#  '32838.jpg',
#  '37940.jpg',
#  '36486.jpg',
#  '30791.jpg',
#  '32186.jpg',
#  '35831.jpg',
#  '33273.jpg',
#  '35602.jpg',
#  '38326.jpg',
#  '37773.jpg',
#  '39986.jpg',
#  '33515.jpg',
#  '33501.jpg',
#  '38454.jpg',
#  '30008.jpg',
#  '39992.jpg',
#  '31316.jpg',
#  '31470.jpg',
#  '33267.jpg',
#  '35616.jpg',
#  '34520.jpg',
#  '35158.jpg',
#  '34246.jpg',
#  '30020.jpg',
#  '39762.jpg',
#  '38468.jpg',
#  '30034.jpg',
#  '32623.jpg',
#  '34534.jpg',
#  '32145.jpg',
#  '36323.jpg',
#  '36874.jpg',
#  '38681.jpg',
#  '31869.jpg',
#  '34911.jpg',
#  '33930.jpg',
#  '34087.jpg',
#  '36690.jpg',
#  '38865.jpg',
#  '31699.jpg',
#  '31841.jpg',
#  '32390.jpg',
#  '32384.jpg',
#  '38871.jpg',
#  '33924.jpg',
#  '34093.jpg',
#  '34078.jpg',
#  '31100.jpg',
#  '38642.jpg',
#  '30578.jpg',
#  '33071.jpg',
#  '33065.jpg',
#  '38130.jpg',
#  '37203.jpg',
#  '39548.jpg',
#  '37565.jpg',
#  '36653.jpg',
#  '34044.jpg',
#  '32435.jpg',
#  '34722.jpg',
#  '36135.jpg',
#  '39206.jpg',
#  '30550.jpg',
#  '34050.jpg',
#  '36647.jpg',
#  '31128.jpg',
#  '36900.jpg',
#  '39399.jpg',
#  '34865.jpg',
#  '36914.jpg',
#  '34859.jpg',
#  '37388.jpg',
#  '31921.jpg',
#  '36928.jpg',
#  '30381.jpg',
#  '32596.jpg',
#  '35212.jpg',
#  '39428.jpg',
#  '31712.jpg',
#  '38050.jpg',
#  '35574.jpg',
#  '33111.jpg',
#  '37377.jpg',
#  '31060.jpg',
#  '35206.jpg',
#  '32569.jpg',
#  '33677.jpg',
#  '34118.jpg',
#  '37439.jpg',
#  '31048.jpg',
#  '36727.jpg',
#  '39414.jpg',
#  '33887.jpg',
#  '34130.jpg',
#  '34656.jpg',
#  '33139.jpg',
#  '32227.jpg',
#  '35548.jpg',
#  '30430.jpg',
#  '30424.jpg',
#  '34642.jpg',
#  '32233.jpg',
#  '32555.jpg',
#  '34124.jpg',
#  '30342.jpg',
#  '39400.jpg',
#  '30815.jpg',
#  '39831.jpg',
#  '39825.jpg',
#  '32970.jpg',
#  '35979.jpg',
#  '38285.jpg',
#  '39819.jpg',
#  '34483.jpg',
#  '31510.jpg',
#  '36519.jpg',
#  '37607.jpg',
#  '38534.jpg',
#  '33461.jpg',
#  '33475.jpg',
#  '37613.jpg',
#  '38520.jpg',
#  '37175.jpg',
#  '38246.jpg',
#  '31504.jpg',
#  '33313.jpg',
#  '30632.jpg',
#  '39170.jpg',
#  '34332.jpg',
#  '39616.jpg',
#  '36525.jpg',
#  '30154.jpg',
#  '36531.jpg',
#  '33449.jpg',
#  '34440.jpg',
#  '39164.jpg',
#  '36257.jpg',
#  '39603.jpg',
#  '36256.jpg',
#  '39165.jpg',
#  '30627.jpg',
#  '35987.jpg',
#  '34455.jpg',
#  '35993.jpg',
#  '32024.jpg',
#  '30633.jpg',
#  '39617.jpg',
#  '32742.jpg',
#  '38521.jpg',
#  '31263.jpg',
#  '35005.jpg',
#  '33474.jpg',
#  '31505.jpg',
#  '37174.jpg',
#  '31511.jpg',
#  '33306.jpg',
#  '32018.jpg',
#  '38535.jpg',
#  '30169.jpg',
#  '36518.jpg',
#  '30182.jpg',
#  '36281.jpg',
#  '34496.jpg',
#  '35950.jpg',
#  '32959.jpg',
#  '32781.jpg',
#  '37821.jpg',
#  '32971.jpg',
#  '39824.jpg',
#  '30800.jpg',
#  '35978.jpg',
#  '30814.jpg',
#  '32232.jpg',
#  '38079.jpg',
#  '30425.jpg',
#  '36732.jpg',
#  '34125.jpg',
#  '32554.jpg',
#  '34131.jpg',
#  '32540.jpg',
#  '33886.jpg',
#  '36726.jpg',
#  '31049.jpg',
#  '37438.jpg',
#  '30431.jpg',
#  '36040.jpg',
#  '34657.jpg',
#  '38045.jpg',
#  '36068.jpg',
#  '34119.jpg',
#  '33676.jpg',
#  '31061.jpg',
#  '37404.jpg',
#  '35575.jpg',
#  '33104.jpg',
#  '37362.jpg',
#  '37389.jpg',
#  '34858.jpg',
#  '38904.jpg',
#  '34694.jpg',
#  '38938.jpg',
#  '33879.jpg',
#  '31908.jpg',
#  '34737.jpg',
#  '35429.jpg',
#  '39213.jpg',
#  '36120.jpg',
#  '31897.jpg',
#  '39575.jpg',
#  '30223.jpg',
#  '39561.jpg',
#  '36652.jpg',
#  '36134.jpg',
#  '38119.jpg',
#  '34723.jpg',
#  '37202.jpg',
#  '35415.jpg',
#  '37564.jpg',
#  '39549.jpg',
#  '37570.jpg',
#  '32408.jpg',
#  '33716.jpg',
#  '33070.jpg',
#  '37216.jpg',
#  '38125.jpg',
#  '31854.jpg',
#  '36685.jpg',
#  '34086.jpg',
#  '35398.jpg',
#  '34938.jpg',
#  '30586.jpg',
#  '36861.jpg',
#  '38858.jpg',
#  '38680.jpg',
#  '36875.jpg',
#  '34904.jpg',
#  '32622.jpg',
#  '37982.jpg',
#  '30035.jpg',
#  '36322.jpg',
#  '32150.jpg',
#  '37028.jpg',
#  '36336.jpg',
#  '39005.jpg',
#  '36450.jpg',
#  '30021.jpg',
#  '34247.jpg',
#  '33528.jpg',
#  '39993.jpg',
#  '38455.jpg',
#  '38333.jpg',
#  '37014.jpg',
#  '31465.jpg',
#  '39039.jpg',
#  '35603.jpg',
#  '33514.jpg',
#  '31303.jpg',
#  '37772.jpg',
#  '37799.jpg',
#  '36487.jpg',
#  '37941.jpg',
#  '34290.jpg',
#  '35830.jpg',
#  '30948.jpg',
#  '35824.jpg',
#  '34284.jpg',
#  '36493.jpg',
#  '38496.jpg',
#  '30974.jpg',
#  '32811.jpg',
#  '39952.jpg',
#  '32813.jpg',
#  '39946.jpg',
#  '30962.jpg',
#  '32185.jpg',
#  '35832.jpg',
#  '34292.jpg',
#  '36485.jpg',
#  '36491.jpg',
#  '35826.jpg',
#  '31473.jpg',
#  '33264.jpg',
#  '33502.jpg',
#  '37764.jpg',
#  '38443.jpg',
#  '37770.jpg',
#  '35167.jpg',
#  '33516.jpg',
#  '33270.jpg',
#  '35601.jpg',
#  '36308.jpg',
#  '31467.jpg',
#  '32146.jpg',
#  '36320.jpg',
#  '39013.jpg',
#  '30989.jpg',
#  '34251.jpg',
#  '34245.jpg',
#  '37994.jpg',
#  '36452.jpg',
#  '39007.jpg',
#  '34912.jpg',
#  '36877.jpg',
#  '38682.jpg',
#  '37599.jpg',
#  '34090.jpg',
#  '30590.jpg',
#  '30584.jpg',
#  '32393.jpg',
#  '36693.jpg',
#  '38866.jpg',
#  '36678.jpg',
#  '30209.jpg',
#  '37566.jpg',
#  '35371.jpg',
#  '37200.jpg',
#  '38133.jpg',
#  '39239.jpg',
#  '35403.jpg',
#  '33072.jpg',
#  '33714.jpg',
#  '38899.jpg',
#  '38641.jpg',
#  '39577.jpg',
#  '38669.jpg',
#  '30553.jpg',
#  '36122.jpg',
#  '34735.jpg',
#  '34721.jpg',
#  '31659.jpg',
#  '39205.jpg',
#  '30221.jpg',
#  '34047.jpg',
#  '36917.jpg',
#  '34866.jpg',
#  '36903.jpg',
#  '33853.jpg',
#  '36095.jpg',
#  '36081.jpg',
#  '33847.jpg',
#  '32581.jpg',
#  '31088.jpg',
#  '38912.jpg',
#  '31063.jpg',
#  '33674.jpg',
#  '39359.jpg',
#  '31705.jpg',
#  '38053.jpg',
#  '34669.jpg',
#  '35211.jpg',
#  '33660.jpg',
#  '37406.jpg',
#  '38735.jpg',
#  '30369.jpg',
#  '31077.jpg',
#  '33890.jpg',
#  '33648.jpg',
#  '34127.jpg',
#  '39403.jpg',
#  '37348.jpg',
#  '34899.jpg',
#  '32230.jpg',
#  '34655.jpg',
#  '32224.jpg',
#  '39371.jpg',
#  '30433.jpg',
#  '39417.jpg',
#  '32542.jpg',
#  '34133.jpg',
#  '38286.jpg',
#  '32973.jpg',
#  '34480.jpg',
#  '33489.jpg',
#  '37823.jpg',
#  '32783.jpg',
#  '35952.jpg',
#  '34494.jpg',
#  '33310.jpg',
#  '31261.jpg',
#  '38523.jpg',
#  '37610.jpg',
#  '39629.jpg',
#  '38537.jpg',
#  '37604.jpg',
#  '35013.jpg',
#  '33304.jpg',
#  '38251.jpg',
#  '37162.jpg',
#  '31513.jpg',
#  '32032.jpg',
#  '38279.jpg',
#  '39167.jpg',
#  '36532.jpg',
#  '30143.jpg',
#  '34325.jpg',
#  '32754.jpg',
#  '32740.jpg',
#  '39615.jpg',
#  '31249.jpg',
#  '30157.jpg',
#  '37638.jpg',
#  '36240.jpg',
#  '35991.jpg',
#  '32741.jpg',
#  '34456.jpg',
#  '33339.jpg',
#  '35748.jpg',
#  '36255.jpg',
#  '30624.jpg',
#  '38278.jpg',
#  '32033.jpg',
#  '32755.jpg',
#  '39600.jpg',
#  '36533.jpg',
#  '35012.jpg',
#  '35774.jpg',
#  '37177.jpg',
#  '38244.jpg',
#  '35006.jpg',
#  '32769.jpg',
#  '33477.jpg',
#  '32782.jpg',
#  '30195.jpg',
#  '34495.jpg',
#  '35953.jpg',
#  '36296.jpg',
#  '37836.jpg',
#  '30181.jpg',
#  '39833.jpg',
#  '30817.jpg',
#  '39199.jpg',
#  '39827.jpg',
#  '36043.jpg',
#  '32543.jpg',
#  '36725.jpg',
#  '39416.jpg',
#  '30354.jpg',
#  '36731.jpg',
#  '30426.jpg',
#  '31738.jpg',
#  '36057.jpg',
#  '38052.jpg',
#  '37361.jpg',
#  '38734.jpg',
#  '35210.jpg',
#  '35204.jpg',
#  '31062.jpg',
#  '37413.jpg',
#  '37375.jpg',
#  '34697.jpg',
#  '30397.jpg',
#  '31089.jpg',
#  '32580.jpg',
#  '33846.jpg',
#  '33852.jpg',
#  '36094.jpg',
#  '31923.jpg',
#  '34683.jpg',
#  '36137.jpg',
#  '37229.jpg',
#  '31880.jpg',
#  '34720.jpg',
#  '34046.jpg',
#  '36889.jpg',
#  '30234.jpg',
#  '32345.jpg',
#  '30552.jpg',
#  '38640.jpg',
#  '37573.jpg',
#  '31102.jpg',
#  '38898.jpg',
#  '35364.jpg',
#  '33715.jpg',
#  '38654.jpg',
#  '37567.jpg',
#  '30208.jpg',
#  '36679.jpg',
#  '31670.jpg',
#  '38132.jpg',
#  '34708.jpg',
#  ...]

# %%
len(a)
# Out:
# 4100

# %%
fp = open('train_failist.txt','a')
for e in a:
    fp.write(e+'\n')
fp.close
# Out:
# <function TextIOWrapper.close()>

# %%
fp = open('train_failist.txt')
a = [f[:-1] for f in fp.readlines()]
len(a)
# Out:
# 18503

# %%
import os
for file in a:
    try:
        os.remove('./train/'+file)
    except:
        continue

# %%
a[0][:-4]
# Out:
# '40270.'
